# %%
from lib.data import get_data
from lib.stats import stage_standing, match_standing

df = get_data("fitds_stages")

# stage_df = stage_standing(df, 'monster_2025', 'P', 1)
# match_df = match_standing(df, 'ma5_1_2026', 'PO')
# Out:
# 2026-03-21 15:46:32.815 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
df.columns
# Out:
# Index(['match_name', 'match_level', 'match_date', 'shooter_name',
#        'shooter_div', 'shooter_class', 'shooter_pf', 'shooter_cat', 'stg_n',
#        'hf', 'time', 'pts', 'a', 'c', 'd', 'ded', 'mi', 'ns', 'pe', 'ot',
#        'championship', 'stg_max_pts', 'pts_pct', 'winner_time',
#        'pct_winner_time', 'stg_max_hf', 'hf_pct', 'stg_match_pts',
#        'hit_factor', 'div_pts_perc', 'div_first_time', 'div_time_perc',
#        'div_factor_perc', 'div_factor_standing', 'cls_pts_perc',
#        'cls_first_time', 'cls_time_perc', 'cls_factor_perc',
#        'cls_factor_standing', 'div_pts_perc_abcd', 'div_first_time_abcd',
#        'div_time_perc_abcd', 'div_factor_perc_abcd',
#        'div_factor_standing_abcd', 'cls_pts_perc_abcd', 'cls_first_time_abcd',
#        'cls_time_perc_abcd', 'cls_factor_perc_abcd',
#        'cls_factor_standing_abcd'],
#       dtype='object')

# %%
# df[(df['shooter_name'] == 'ABATECOLA, CHRISTIAN') & (df['match_name'] == 'ma5_2_2025')]

# %%
preds = get_data("class_predict")
preds
# preds[preds['shooter_name'].str.contains('BUZZELLI') & (preds['match_name'] == 'beretta_2025')]
# Out:
# 2026-03-18 15:42:13.173 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-18 15:42:13.175 WARNING streamlit.runtime.state.session_state_proxy: Session state does not function when running a script without `streamlit run`
# 2026-03-18 15:42:13.191 No runtime found, using MemoryCacheStorageManager
# 2026-03-18 15:42:13.215 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-18 15:42:13.216 No runtime found, using MemoryCacheStorageManager
#                shooter_name    match_name shooter_div  n_stages  sh_median  \
# 0      ABATECOLA, CHRISTIAN  beretta_2025          PO        14   0.585387
# 1      ABATECOLA, CHRISTIAN  beretta_2025          PO        14   0.585387
# 2      ABATECOLA, CHRISTIAN  beretta_2025          PO        14   0.585387
# 3      ABATECOLA, CHRISTIAN  beretta_2025          PO        14   0.585387
# 4      ABATECOLA, CHRISTIAN  beretta_2025          PO        14   0.585387
# ...                     ...           ...         ...       ...        ...
# 10108       ZULLO, EMANUELE    ma5_2_2026           S         8   0.334255
# 10109       ZULLO, EMANUELE    ma5_3_2025           P         8   0.344786
# 10110       ZULLO, EMANUELE    ma5_3_2025           P         8   0.344786
# 10111       ZULLO, EMANUELE    ma5_3_2025           P         8   0.344786
# 10112       ZULLO, EMANUELE    ma5_3_2025           P         8   0.344786
#
#       shooter_class  n_in_class        q1  class_median        q3  within_iqr  \
# 0                 A        19.0  0.622755      0.654609  0.691889       False
# 1                 B        14.0  0.555645      0.582565  0.591998        True
# 2                 C        11.0  0.451119      0.483825  0.527232       False
# 3                 G        11.0  0.718027      0.788091  0.840132       False
# 4                 M        16.0  0.744918      0.764686  0.794368       False
# ...             ...         ...       ...           ...       ...         ...
# 10108             D         8.0  0.415015      0.459374  0.512803       False
# 10109             A         8.0  0.685399      0.722150  0.746556       False
# 10110             B        23.0  0.594340      0.643709  0.699349       False
# 10111             C        40.0  0.420064      0.518584  0.556904       False
# 10112             D        47.0  0.346060      0.395992  0.455707       False
#
#        dist_to_class_median  _within_rank
# 0                  0.069222             1
# 1                  0.002822             0
# 2                  0.101562             1
# 3                  0.202704             1
# 4                  0.179299             1
# ...                     ...           ...
# 10108              0.125119             1
# 10109              0.377364             1
# 10110              0.298923             1
# 10111              0.173798             1
# 10112              0.051206             1
#
# [9315 rows x 13 columns]
