# %%
from lib.data import get_data
from lib.stats import stage_standing, match_standing

df = get_data("fitds_stages")


# stage_df = stage_standing(df, 'monster_2025', 'P', 1)
# match_df = match_standing(df, 'ma5_1_2026', 'PO')
# Out:
# 2026-04-14 15:58:45.776 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2026-04-14 15:58:45.778 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2026-04-14 15:58:45.778 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2026-04-14 15:58:45.780 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-14 15:58:45.781 WARNING streamlit.runtime.state.session_state_proxy: Session state does not function when running a script without `streamlit run`
# 2026-04-14 15:58:45.784 No runtime found, using MemoryCacheStorageManager

# %%
df.columns
# Out:
# Index(['match_name', 'match_level', 'match_date', 'shooter_name',
#        'shooter_div', 'shooter_class', 'shooter_pf', 'shooter_cat', 'stg_n',
#        'hf', 'time', 'pts', 'a', 'c', 'd', 'ded', 'mi', 'ns', 'pe', 'ot',
#        'championship', 'stg_max_pts', 'pts_pct', 'winner_time',
#        'pct_winner_time', 'stg_max_hf', 'hf_pct', 'stg_match_pts',
#        'hit_factor', 'div_pts_perc', 'div_first_time', 'div_time_perc',
#        'div_factor_perc', 'div_factor_standing', 'cls_pts_perc',
#        'cls_first_time', 'cls_time_perc', 'cls_factor_perc',
#        'cls_factor_standing', 'div_pts_perc_abcd', 'div_first_time_abcd',
#        'div_time_perc_abcd', 'div_factor_perc_abcd',
#        'div_factor_standing_abcd', 'cls_pts_perc_abcd', 'cls_first_time_abcd',
#        'cls_time_perc_abcd', 'cls_factor_perc_abcd',
#        'cls_factor_standing_abcd'],
#       dtype='object')

# %%
df['championship'].unique()
# Out:
# array(['Campionato Federale', 'No championship', 'Campionato Italiano',
#        'Winter Championship'], dtype=object)

# %%
# df[(df['shooter_name'] == 'ABATECOLA, CHRISTIAN') & (df['match_name'] == 'ma5_2_2025')]

# %%
preds = get_data("class_predict")
preds
# preds[preds['shooter_name'].str.contains('BUZZELLI') & (preds['match_name'] == 'beretta_2025')]
# Out:
# 2026-04-14 15:58:51.128 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-14 15:58:51.130 No runtime found, using MemoryCacheStorageManager
# 2026-04-14 15:58:51.130 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
#               shooter_name    match_name shooter_div  n_stages  sh_median  \
# 0     ABATECOLA, CHRISTIAN  beretta_2025          PO        14   0.585387
# 1     ABATECOLA, CHRISTIAN    ma5_2_2025          PO         8   0.782468
# 2     ABATECOLA, CHRISTIAN    ma5_3_2025          PO         7   0.765470
# 3     ABATECOLA, CHRISTIAN    ma5_3_2026          PO         8   0.740898
# 4     ABATECOLA, CHRISTIAN    ma5_4_2025          PO         8   0.804455
# ...                    ...           ...         ...       ...        ...
# 3591       ZULLO, EMANUELE    ita_4_2025           P        10   0.316137
# ...
