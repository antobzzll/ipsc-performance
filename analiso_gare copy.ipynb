# %%
from lib.data import get_data
from lib.stats import stage_standing, match_standing

df = get_data("fitds_stages")

stage_df = stage_standing(df, 'monster_2025', 'P', 1)
match_df = match_standing(df, 'ma5_1_2026', 'PO')
# Out:
# 2026-03-15 22:29:09.338 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2026-03-15 22:29:09.339 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2026-03-15 22:29:09.340 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2026-03-15 22:29:09.342 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-15 22:29:09.342 WARNING streamlit.runtime.state.session_state_proxy: Session state does not function when running a script without `streamlit run`
# 2026-03-15 22:29:09.345 No runtime found, using MemoryCacheStorageManager

# %%
df[df['match_name'] == 'christmas_2025']
# Out:
#            match_name  match_level  match_date                 shooter_name  \
# 27548  christmas_2025            3  2025-12-14  SANTARCANGELO, ADRIANO CIRO
# 27549  christmas_2025            3  2025-12-14  SANTARCANGELO, ADRIANO CIRO
# 27550  christmas_2025            3  2025-12-14  SANTARCANGELO, ADRIANO CIRO
# 27551  christmas_2025            3  2025-12-14  SANTARCANGELO, ADRIANO CIRO
# 27552  christmas_2025            3  2025-12-14  SANTARCANGELO, ADRIANO CIRO
# ...               ...          ...         ...                          ...
# 30603  christmas_2025            3  2025-12-14          RUSSO, MASSIMILIANO
# 30604  christmas_2025            3  2025-12-14          RUSSO, MASSIMILIANO
# 30605  christmas_2025            3  2025-12-14          RUSSO, MASSIMILIANO
# 30606  christmas_2025            3  2025-12-14          RUSSO, MASSIMILIANO
# 30607  christmas_2025            3  2025-12-14          RUSSO, MASSIMILIANO
#
#       shooter_div shooter_class shooter_pf shooter_cat  stg_n      hf  ...  \
# 27548           S             G      Major          SS      1  7.1152  ...
# 27549           S             G      Major          SS      2  5.8824  ...
# 27550           S             G      Major          SS      3  5.3521  ...
# 27551           S             G      Major          SS      4  7.3511  ...
# 27552           S             G      Major          SS      5  7.3155  ...
# ...           ...           ...        ...         ...    ...     ...  ...
# 30603           P             A      Minor         NaN      8  4.3059  ...
# 30604           P             A      Minor         NaN      9  3.6166  ...
# 30605           P             A      Minor         NaN     10  6.1442  ...
# 30606           P             A      Minor         NaN     11  6.0134  ...
# 30607           P             A      Minor         NaN     12  6.8060  ...
#
#        div_pts_perc_abcd  div_first_time_abcd  div_time_perc_abcd  \
# 27548                NaN                  NaN                 NaN
# 27549                NaN                  NaN                 NaN
# 27550                NaN                  NaN                 NaN
# 27551                NaN                  NaN                 NaN
# 27552                NaN                  NaN                 NaN
# ...                  ...                  ...                 ...
# 30603           0.966667                11.50            0.789161
# 30604           1.000000                12.19            0.681133
# 30605           0.975000                22.47            0.838125
# 30606           0.931034                 8.36            0.930958
# 30607           0.950000                16.68            0.995821
#
#        div_factor_perc_abcd  div_factor_standing_abcd  cls_pts_perc_abcd  \
# 27548                   NaN                       NaN                NaN
# 27549                   NaN                       NaN                NaN
# 27550                   NaN                       NaN                NaN
# 27551                   NaN                       NaN                NaN
# 27552                   NaN                       NaN                NaN
# ...                     ...                       ...                ...
# 30603              0.884241                      14.0           0.966667
# 30604              0.791292                      21.0           1.000000
# 30605              0.908287                       5.0           1.000000
# 30606              1.000000                       1.0           0.964286
# 30607              1.000000                       1.0           0.982759
#
#        cls_first_time_abcd  cls_time_perc_abcd  cls_factor_perc_abcd  \
# 27548                  NaN                 NaN                   NaN
# 27549                  NaN                 NaN                   NaN
# 27550                  NaN                 NaN                   NaN
# 27551                  NaN                 NaN                   NaN
# 27552                  NaN                 NaN                   NaN
# ...                    ...                 ...                   ...
# 30603                11.50            0.853749              0.905000
# 30604                13.34            0.804099              0.831823
# 30605                22.56            0.888539              0.924093
# 30606                 8.98            1.000000              1.000000
# 30607                16.75            1.000000              1.000000
#
#        cls_factor_standing_abcd
# 27548                       NaN
# 27549                       NaN
# 27550                       NaN
# 27551                       NaN
# 27552                       NaN
# ...                         ...
# 30603                       4.0
# 30604                       5.0
# 30605                       4.0
# 30606                       1.0
# 30607                       1.0
#
# [3060 rows x 49 columns]

# %%
df[(df['shooter_name'] == 'ABATECOLA, CHRISTIAN') & (df['match_name'] == 'ma5_2_2025')]
# Out:
#       match_name  match_level  match_date          shooter_name shooter_div  \
# 1328  ma5_2_2025            2  2025-02-23  ABATECOLA, CHRISTIAN          PO
# 1329  ma5_2_2025            2  2025-02-23  ABATECOLA, CHRISTIAN          PO
# 1330  ma5_2_2025            2  2025-02-23  ABATECOLA, CHRISTIAN          PO
# 1331  ma5_2_2025            2  2025-02-23  ABATECOLA, CHRISTIAN          PO
# 1332  ma5_2_2025            2  2025-02-23  ABATECOLA, CHRISTIAN          PO
# 1333  ma5_2_2025            2  2025-02-23  ABATECOLA, CHRISTIAN          PO
# 1334  ma5_2_2025            2  2025-02-23  ABATECOLA, CHRISTIAN          PO
# 1335  ma5_2_2025            2  2025-02-23  ABATECOLA, CHRISTIAN          PO
#
#      shooter_class shooter_pf shooter_cat  stg_n      hf  ...  \
# 1328             B      Minor         NaN      1  4.6523  ...
# 1329             B      Minor         NaN      2  3.5685  ...
# 1330             B      Minor         NaN      3  6.8875  ...
# 1331             B      Minor         NaN      4  5.5264  ...
# 1332             B      Minor         NaN      5  4.5313  ...
# 1333             B      Minor         NaN      6  5.1048  ...
# 1334             B      Minor         NaN      7  4.6656  ...
# 1335             B      Minor         NaN      8  6.6667  ...
#
#       div_pts_perc_abcd  div_first_time_abcd  div_time_perc_abcd  \
# 1328           0.833333                15.19            0.743879
# 1329           0.716667                10.99            0.912033
# 1330           1.000000                17.87            0.778989
# 1331           0.983051                15.47            0.737018
# 1332           0.966667                10.24            0.800000
# 1333           0.965517                 7.77            0.708295
# 1334           1.000000                11.27            0.832815
# 1335           1.000000                19.35            0.748333
#
#       div_factor_perc_abcd  div_factor_standing_abcd  cls_pts_perc_abcd  \
# 1328              0.673719                      11.0           0.833333
# 1329              0.700324                       3.0           0.741379
# 1330              0.854719                       4.0           1.000000
# 1331              0.777217                      12.0           1.000000
# 1332              0.828555                       7.0           1.000000
# 1333              0.735636                       7.0           0.965517
# 1334              0.906575                       5.0           1.000000
# 1335              0.848688                       8.0           1.000000
#
#       cls_first_time_abcd  cls_time_perc_abcd  cls_factor_perc_abcd  \
# 1328                17.88            0.875612              0.815521
# 1329                12.05            1.000000              1.000000
# 1330                21.41            0.933304              1.000000
# 1331                19.06            0.908051              0.957582
# 1332                12.80            1.000000              1.000000
# 1333                 9.38            0.855059              0.855061
# 1334                12.03            0.935459              0.935459
# 1335                23.41            0.975417              0.987762
#
#       cls_factor_standing_abcd
# 1328                       3.0
# 1329                       1.0
# 1330                       1.0
# 1331                       4.0
# 1332                       1.0
# 1333                       2.0
# 1334                       2.0
# 1335                       2.0
#
# [8 rows x 49 columns]
