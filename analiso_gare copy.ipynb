# %%
from lib.data import get_data
from lib.stats import stage_standing, match_standing

df = get_data("fitds_stages")

stage_df = stage_standing(df, 'monster_2025', 'P', 1)
match_df = match_standing(df, 'monster_2025', 'P')
# Out:
# 2026-03-13 13:58:13.470 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2026-03-13 13:58:13.471 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2026-03-13 13:58:13.472 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2026-03-13 13:58:13.475 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-13 13:58:13.475 WARNING streamlit.runtime.state.session_state_proxy: Session state does not function when running a script without `streamlit run`
# 2026-03-13 13:58:13.477 No runtime found, using MemoryCacheStorageManager

# %%
match_df
# Out:
#    shooter_div  rank               shooter_name shooter_class  stg_match_pts  \
# 0            P     1       PERAZZOLI, FRANCESCO             G       1792.046
# 1            P     2            SÁNCHEZ, CARLOS           NaN       1769.958
# 2            P     3             BERGAMO, BRICE           NaN       1729.782
# 3            P     4  BUTICCHI, EDOARDO ROBERTO             G       1700.134
# 4            P     5          PIGNATTI, ALBERTO             M       1672.716
# ..         ...   ...                        ...           ...            ...
# 70           P    71           VITALI, FEDERICA             D        707.370
# 71           P    72         AMBROSIO, CRISTIAN             D        706.210
# 72           P    73        BONFANTI, FRANCESCO             D        602.480
# 73           P    74            SALEMI, ALBERTO             C        532.536
# 74           P    75      FANTINATI, ALESSANDRO             D          0.000
#
#        pct
# 0   1.0000
# 1   0.9877
# 2   0.9653
# 3   0.9487
# 4   0.9334
# ..     ...
# 70  0.3947
# 71  0.3941
# 72  0.3362
# 73  0.2972
# 74  0.0000
#
# [75 rows x 6 columns]
