# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\antob\Documents\MEGA\Documenti\Armi\Gare\app\ipsc-performance\data\IPSC.csv')
df
# Out:
#        match_name  match_level  match_date              shooter div class  \
# 0      2025_MA5_2            2  2025-02-23   DEL CANUTO, ANDREA   S     C
# 1      2025_MA5_2            2  2025-02-23        LAURO, ANDREA   P     D
# 2      2025_MA5_2            2  2025-02-23        LAURO, ANDREA   P     D
# 3      2025_MA5_2            2  2025-02-23    SOLIDANI, TOMMASO   C     A
# 4      2025_MA5_2            2  2025-02-23    SOLIDANI, TOMMASO   C     A
# ...           ...          ...         ...                  ...  ..   ...
# 26573   2025_W4_5            2  2025-11-30    TAGLIATI, ROBERTO  SO     B
# 26574   2025_W4_5            2  2025-11-30    TAGLIATI, ROBERTO  SO     B
# 26575   2025_W4_5            2  2025-11-30    TAGLIATI, ROBERTO  SO     B
# 26576   2025_W4_5            2  2025-11-30   FEDELI, ALESSANDRO   C     A
# 26577   2025_W4_5            2  2025-11-30  BALESTRINI, BARBARA  PO     A
#
#       power_factor  cat      stg  factor  pts   a  c  d  ded  mi  ns  pe  ot  \
# ...

# %%
df[df['shooter'] == 'BUZZELLI, ANTONIO'].groupby('match_name').agg({'stg': 'size'})
# Out:
#               stg
# match_name
# 2025_BERETTA   14
# 2025_ITA_4     10
# 2025_MA5_2      8
# 2025_MA5_3      8
# 2025_MA5_4      8
# 2025_MA5_5      8
# 2025_MONSTER   20
# 2025_W4_2       6
# 2025_W4_5       6
# 2025_W5_1       6
# 2025_W5_2       6
# 2025_W5_3       6
# 2025_W5_4       6
